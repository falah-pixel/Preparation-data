# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_produk.csv')

# %%
df.head()
# Out:
#                item_name                                        description  \
# 0        Sepatu Sneakers  Sepatu Sneakers adalah pilihan yang sempurna u...
# 1     Tas Ransel Stylish  Tas Ransel Stylish memberikan gaya dan fungsi ...
# 2   Kemeja Flanel Modern  Kemeja Flanel Modern memberikan tampilan yang ...
# 3  Celana Jeans Slim Fit  Celana Jeans Slim Fit adalah pilihan yang tepa...
# 4     Topi Fedora Elegan  Topi Fedora Elegan memberikan sentuhan klasik ...
#
#   category   price   colour         shop_name
# 0   Sepatu  100000    Putih   Home Essentials
# 1      Tas  200000    Merah      Sports World
# 2   Kemeja  150000    Hijau  Gourmet Delights
# 3   Celana  250000     Biru        Gadget Hub
# 4     Topi   50000  Abu-abu  Gourmet Delights

# %%
df.tail()
# Out:
#                    item_name  \
# 95        Tas Crossbody Chic
# 96  Gelang Manik-Manik Etnik
# 97       Parfum Musk Sensual
# 98      Sweater Rajut Elegan
# 99        Celana Kulot Modis
#
#                                           description category   price  \
# 95  Tas Crossbody Chic memberikan gaya yang chic d...      Tas   70000
# 96  Gelang Manik-Manik Etnik memberikan sentuhan g...   Gelang   50000
# 97  Parfum Musk Sensual memberikan aroma yang sens...   Parfum  150000
# 98  Sweater Rajut Elegan memberikan kenyamanan dan...  Sweater  200000
# 99  Celana Kulot Modis memberikan tampilan yang mo...   Celana   90000
#
#      colour          shop_name
# 95    Putih       Sports World
# 96    Hitam       Sports World
# 97  Cokelat    Wellness Center
# 98    Merah  Vintage Treasures
# 99    Hitam    Wellness Center

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   item_name    100 non-null    object
#  1   description  100 non-null    object
#  2   category     100 non-null    object
#  3   price        100 non-null    int64
#  4   colour       100 non-null    object
#  5   shop_name    100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#                price
# count     100.000000
# mean   124600.000000
# std     80959.149195
# min     30000.000000
# 25%     70000.000000
# 50%    100000.000000
# 75%    150000.000000
# max    500000.000000

# %%
df.isnull().sum()
# Out:
# item_name    0
# category     0
# price        0
# colour       0
# shop_name    0
# dtype: int64

# %%
df= df.drop(columns=['description'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_name  100 non-null    object
#  1   category   100 non-null    object
#  2   price      100 non-null    int64
#  3   colour     100 non-null    object
#  4   shop_name  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in ['item_name','category','colour','shop_name']:
    if col in df.columns:
        df[col] = le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_name  100 non-null    int64
#  1   category   100 non-null    int64
#  2   price      100 non-null    int64
#  3   colour     100 non-null    int64
#  4   shop_name  100 non-null    int64
# dtypes: int64(5)
# memory usage: 4.0 KB

# %%
df.head()
# Out:
#    item_name  category   price  colour  shop_name
# 0         76        27  100000      10         13
# 1         88        30  200000       7         20
# 2         48        21  150000       4         10
# 3         14         8  250000       1          7
# 4         96        35   50000       0         10

# %%
import matplotlib.pyplot as plt
corr = df.corr(numeric_only=True)

# tampilkan matriks korelasi sebagai heatmap
plt.figure(figsize=(10, 6))
plt.imshow(corr, cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Correlation')
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Matrix (data_produk)")
plt.tight_layout()
plt.show()
